# %% [markdown]
# <a href="https://colab.research.google.com/github/jessamcs/Week4Repository/blob/main/Recreate2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.ticker as ticker

from matplotlib.dates import DateFormatter
from matplotlib.pyplot import figure

# %%
filename = '/content/mortgages (3).csv'

df = pd.read_csv(filename)

# The black line is the 30 year mortgage at 5% and the blue line is the 30 year mortgage at 3%. 
#What is graphed is the cumulative interest paid over the course of the loan. 
#Hint: plt.xticks(fontsize = 15) and plt.yticks(fontsize = 15) might be useful to make the ticks bigger. 

year30_filter = df['Mortgage Name'] == '30 Year'
Mortage30 = df[df['Mortgage Name'] == '30 Year']

# %%
percent3_filter = df['Interest Rate'] == 0.03
percent3_filter
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 1075    False
# 1076    False
# 1077    False
# 1078    False
# 1079    False
# Name: Interest Rate, Length: 1080, dtype: bool

# %%
a = df.loc[year30_filter & percent3_filter, :]

# %%
percent5_filter = df['Interest Rate'] == 0.05
b = df.loc[year30_filter & percent5_filter, :]

# %%
fig, axes = plt.subplots(nrows = 1, ncols = 1, figsize=(10,5));
axes.locator_params(axis='y', nbins=10)
axes.title.set_text('Cumulative Interest Paid')
axes.title.set_fontsize('xx-large')
axes.xaxis.set_label_text('Month', fontsize='xx-large')
axes.yaxis.set_label_text('Dollar', fontsize='xx-large')
axes.tick_params(axis='both', labelsize=15)
axes.plot(b['Month'], b['Interest Paid'].cumsum(), label='30 Years 5% APR', c='k')
axes.plot(a['Month'], a['Interest Paid'].cumsum(), label='30 Years 3% APR', c='b')
axes.legend(loc='lower right', bbox_to_anchor=(0.45, 0.1, 0.5, 0.5))
